# %% [markdown]
# # **Data Manipulation**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car-sales.csv')

# %%
# fetching first five rows
df.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White        35431.0    4.0  15323
# 1     BMW   Blue       192714.0    5.0  19943
# 2   Honda  White        84714.0    4.0  28343
# 3  Toyota  White       154365.0    4.0  13434
# 4  Nissan   Blue       181577.0    3.0  14043

# %%
# fetching last 5 rows
df.tail(5)
# Out:
#       Make Colour  Odometer (KM)  Doors  Price
# 94   Honda  Green       130076.0    4.0   6762
# 95   Honda   Blue       143707.0    4.0  16337
# 96  Toyota   Blue        29856.0    4.0  11392
# 97  Toyota  Black       133433.0    4.0  16519
# 98  Toyota    Red       147455.0    4.0  22296

# %%
# getting basic statitical information
df.describe()
# Out:
#        Odometer (KM)      Doors         Price
# count      95.000000  94.000000     99.000000
# mean   131522.294737   4.000000  14896.838384
# std     63363.455998   0.387992   8009.943192
# min     16933.000000   3.000000   3300.000000
# 25%     82411.000000   4.000000   8371.000000
# 50%    130783.000000   4.000000  13698.000000
# 75%    183227.500000   4.000000  19135.500000
# max    248447.000000   5.000000  48686.000000

# %%
df.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)    float64
# Doors            float64
# Price              int64
# dtype: object

# %% [markdown]
# ### Handling missing values

# %%
# getting missing values
# True: value is not there
# False: value is there

df.isnull()
# Out:
#      Make  Colour  Odometer (KM)  Doors  Price
# 0   False   False          False  False  False
# 1   False   False          False  False  False
# 2   False   False          False  False  False
# 3   False   False          False  False  False
# 4   False   False          False  False  False
# ..    ...     ...            ...    ...    ...
# 94  False   False          False  False  False
# 95  False   False          False  False  False
# 96  False   False          False  False  False
# 97  False   False          False  False  False
# 98  False   False          False  False  False
#
# [99 rows x 5 columns]

# %%
# cheching by column

df.isnull().any()
# Out:
# Make              True
# Colour            True
# Odometer (KM)     True
# Doors             True
# Price            False
# dtype: bool

# %%
# cheching by rows

df.isnull().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool

# %%
# geting to know how many values are missing in each column

df.isnull().sum()
# Out:
# Make             7
# Colour           5
# Odometer (KM)    4
# Doors            5
# Price            0
# dtype: int64

# %%
df.head(10)

# we see there is a NaN (missing value) in row no 7
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White        35431.0    4.0  15323
# 1     BMW   Blue       192714.0    5.0  19943
# 2   Honda  White        84714.0    4.0  28343
# 3  Toyota  White       154365.0    4.0  13434
# 4  Nissan   Blue       181577.0    3.0  14043
# 5   Honda    Red        42652.0    4.0  23883
# 6  Toyota   Blue       163453.0    4.0   8473
# 7   Honda  White            NaN    4.0  20306
# 8     NaN  White       130538.0    4.0   9374
# 9   Honda   Blue        51029.0    4.0  26683

# %%
# temporarily filling missing values with 0

df_filled = df.fillna(0)

# %%
df_filled.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White        35431.0    4.0  15323
# 1     BMW   Blue       192714.0    5.0  19943
# 2   Honda  White        84714.0    4.0  28343
# 3  Toyota  White       154365.0    4.0  13434
# 4  Nissan   Blue       181577.0    3.0  14043
# 5   Honda    Red        42652.0    4.0  23883
# 6  Toyota   Blue       163453.0    4.0   8473
# 7   Honda  White            0.0    4.0  20306
# 8       0  White       130538.0    4.0   9374
# 9   Honda   Blue        51029.0    4.0  26683

# %%
# although this is not a right way to do it so we gonna fill the missing values with the mean of the column

df['Odometer (KM) filled'] = df['Odometer (KM)'].fillna(df['Odometer (KM)'].mean())

# %%
# the ododmeter column is not filled with it's mean

df.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Odometer (KM) filled
# 0   Honda  White        35431.0    4.0  15323          35431.000000
# 1     BMW   Blue       192714.0    5.0  19943         192714.000000
# 2   Honda  White        84714.0    4.0  28343          84714.000000
# 3  Toyota  White       154365.0    4.0  13434         154365.000000
# 4  Nissan   Blue       181577.0    3.0  14043         181577.000000
# 5   Honda    Red        42652.0    4.0  23883          42652.000000
# 6  Toyota   Blue       163453.0    4.0   8473         163453.000000
# 7   Honda  White            NaN    4.0  20306         131522.294737
# 8     NaN  White       130538.0    4.0   9374         130538.000000
# 9   Honda   Blue        51029.0    4.0  26683          51029.000000

# %%
# renaming a column
df = df.rename(columns={'Odometer (KM)': 'Odometer_reading'})
df
# Out:
#       Make Colour  Odometer_reading  Doors  Price  Odometer (KM) filled
# 0    Honda  White           35431.0    4.0  15323               35431.0
# 1      BMW   Blue          192714.0    5.0  19943              192714.0
# 2    Honda  White           84714.0    4.0  28343               84714.0
# 3   Toyota  White          154365.0    4.0  13434              154365.0
# 4   Nissan   Blue          181577.0    3.0  14043              181577.0
# ..     ...    ...               ...    ...    ...                   ...
# 94   Honda  Green          130076.0    4.0   6762              130076.0
# 95   Honda   Blue          143707.0    4.0  16337              143707.0
# 96  Toyota   Blue           29856.0    4.0  11392               29856.0
# 97  Toyota  Black          133433.0    4.0  16519              133433.0
# 98  Toyota    Red          147455.0    4.0  22296              147455.0
#
# [99 rows x 6 columns]

# %%
# changing data type of any column

df['doors_new'] = df['Doors'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[17], line 3
#       1 # changing data type of any column
# ----> 3 df['doors_new'] = df['Doors'].astype(int)
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:140, in astype_nansafe(arr, dtype, copy, skipna)
#     137     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#     139 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 140     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     142 elif is_object_dtype(arr.dtype):
#     143
#     144     # if we have a datetime/timedelta array of objects
#     145     # then coerce to a proper dtype and recall astype_nansafe
#     147     if is_datetime64_dtype(dtype):
#
# File c:\Users\91977\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:182, in _astype_float_to_int_nansafe(values, dtype, copy)
#     178 """
#     179 astype with a check preventing converting NaN to an meaningless integer value.
#     180 """
#     181 if not np.isfinite(values).all():
# --> 182     raise IntCastingNaNError(
#     183         "Cannot convert non-finite values (NA or inf) to integer"
#     184     )
#     185 if dtype.kind == "u":
#     186     # GH#45151
#     187     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# The above error because the door column has some missing values

# %%
df['Doors'] = df['Doors'].fillna(df['Doors'].mean())

# %%
df['doors_new'] = df['Doors'].astype(int)

# %%
df.head(10)
# Out:
#      Make Colour  Odometer_reading  Doors  Price  Odometer (KM) filled  \
# 0   Honda  White           35431.0    4.0  15323          35431.000000
# 1     BMW   Blue          192714.0    5.0  19943         192714.000000
# 2   Honda  White           84714.0    4.0  28343          84714.000000
# 3  Toyota  White          154365.0    4.0  13434         154365.000000
# 4  Nissan   Blue          181577.0    3.0  14043         181577.000000
# 5   Honda    Red           42652.0    4.0  23883          42652.000000
# 6  Toyota   Blue          163453.0    4.0   8473         163453.000000
# 7   Honda  White               NaN    4.0  20306         131522.294737
# 8     NaN  White          130538.0    4.0   9374         130538.000000
# 9   Honda   Blue           51029.0    4.0  26683          51029.000000
#
#    doors_new
# 0          4
# 1          5
# 2          4
# 3          4
# 4          3
# 5          4
# 6          4
# 7          4
# 8          4
# 9          4

# %%
# changing all the values of a column using lambda function
# for eg, increasing the price by 10%

df['new price'] = df['Price'].apply(lambda x:x+x/10)
df.head(10)
# Out:
#      Make Colour  Odometer_reading  Doors  Price  Odometer (KM) filled  \
# 0   Honda  White           35431.0    4.0  15323          35431.000000
# 1     BMW   Blue          192714.0    5.0  19943         192714.000000
# 2   Honda  White           84714.0    4.0  28343          84714.000000
# 3  Toyota  White          154365.0    4.0  13434         154365.000000
# 4  Nissan   Blue          181577.0    3.0  14043         181577.000000
# 5   Honda    Red           42652.0    4.0  23883          42652.000000
# 6  Toyota   Blue          163453.0    4.0   8473         163453.000000
# 7   Honda  White               NaN    4.0  20306         131522.294737
# 8     NaN  White          130538.0    4.0   9374         130538.000000
# 9   Honda   Blue           51029.0    4.0  26683          51029.000000
#
#    new price
# 0    16855.3
# 1    21937.3
# 2    31177.3
# 3    14777.4
# 4    15447.3
# 5    26271.3
# 6     9320.3
# 7    22336.6
# 8    10311.4
# 9    29351.3

# %%
# can declare a separate function also

df.drop('new price', axis=1)
def changePrice(n):
    n1 = n/5+100
    return n1

df['new price'] = df['Price'].apply(lambda x:changePrice(x))
df.head(10)
# Out:
#      Make Colour  Odometer_reading  Doors  Price  Odometer (KM) filled  \
# 0   Honda  White           35431.0    4.0  15323          35431.000000
# 1     BMW   Blue          192714.0    5.0  19943         192714.000000
# 2   Honda  White           84714.0    4.0  28343          84714.000000
# 3  Toyota  White          154365.0    4.0  13434         154365.000000
# 4  Nissan   Blue          181577.0    3.0  14043         181577.000000
# 5   Honda    Red           42652.0    4.0  23883          42652.000000
# 6  Toyota   Blue          163453.0    4.0   8473         163453.000000
# 7   Honda  White               NaN    4.0  20306         131522.294737
# 8     NaN  White          130538.0    4.0   9374         130538.000000
# 9   Honda   Blue           51029.0    4.0  26683          51029.000000
#
#    new price
# 0     3164.6
# 1     4088.6
# 2     5768.6
# 3     2786.8
# 4     2908.6
# 5     4876.6
# 6     1794.6
# 7     4161.2
# 8     1974.8
# 9     5436.6

# %%
# Grouping data
# finding mean price of cars by each color

grouped_price_mean = df.groupby('Colour')['Price'].mean()
print(grouped_price_mean)
# Out:
# Colour
# Black     9968.000000
# Blue     14240.162162
# Green    13374.444444
# Red      20263.000000
# White    15075.323529
# Name: Price, dtype: float64

# %%
# on the basis of more than one columns

grouped_mean = df.groupby(['Make', 'Colour'])['Price'].mean()
print(grouped_mean)
# Out:
# Make    Colour
# BMW     Blue      19943.000000
#         Red       21927.000000
#         White     29159.500000
# Honda   Black      8903.000000
#         Blue      17061.250000
#         Green     16885.200000
#         Red       23883.000000
#         White     13122.300000
# Nissan  Blue      12150.111111
#         Green      7970.000000
#         Red       18160.000000
#         White     12628.125000
# Toyota  Black     11033.000000
#         Blue      12506.333333
#         Green     10002.000000
#         Red       21402.000000
#         White     15078.428571
# Name: Price, dtype: float64

# %%
# applying more functions

grouped_stats = df.groupby(['Make', 'Colour'])['Price'].agg(['mean', 'sum', 'count'])
print(grouped_stats)
# Out:
#                        mean     sum  count
# Make   Colour
# BMW    Blue    19943.000000   19943      1
#        Red     21927.000000   43854      2
#        White   29159.500000  116638      4
# Honda  Black    8903.000000   26709      3
#        Blue    17061.250000  136490      8
#        Green   16885.200000   84426      5
#        Red     23883.000000   23883      1
#        White   13122.300000  131223     10
# Nissan Blue    12150.111111  109351      9
#        Green    7970.000000   15940      2
#        Red     18160.000000   18160      1
#        White   12628.125000  101025      8
# Toyota Black   11033.000000   33099      3
#        Blue    12506.333333  225114     18
#        Green   10002.000000   20004      2
#        Red     21402.000000   64206      3
#        White   15078.428571  105549      7

# %% [markdown]
# ### Joins

# %%
d1 = {
    'Key': ['A', 'B', 'C'],
    'Value': [1, 2, 3]
}

d2 = {
    'Key': ['B', 'C', 'D'],
    'Value': [4, 5, 6]
}

dt1 = pd.DataFrame(d1)
dt2 = pd.DataFrame(d2)

# %%
dt1
# Out:
#   Key  Value
# 0   A      1
# 1   B      2
# 2   C      3

# %%
dt2
# Out:
#   Key  Value
# 0   B      4
# 1   C      5
# 2   D      6

# %%
# inner join: basically intersection

pd.merge(dt1, dt2, on='Key', how='inner')
# Out:
#   Key  Value_x  Value_y
# 0   B        2        4
# 1   C        3        5

# %%
# outer join: basically union

pd.merge(dt1, dt2, on='Key', how='outer')
# Out:
#   Key  Value_x  Value_y
# 0   A      1.0      NaN
# 1   B      2.0      4.0
# 2   C      3.0      5.0
# 3   D      NaN      6.0

# %%
# left join and right join

pd.merge(dt1, dt2, on='Key', how='left')
# Out:
#   Key  Value_x  Value_y
# 0   A        1      NaN
# 1   B        2      4.0
# 2   C        3      5.0

# %%
pd.merge(dt1, dt2, on='Key', how='right')
# Out:
#   Key  Value_x  Value_y
# 0   B      2.0        4
# 1   C      3.0        5
# 2   D      NaN        6
